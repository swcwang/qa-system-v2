# %%
import sys
print(sys.executable)  # Should show your .venv path
# Out:
# /Users/swang/workspace/repos/qanda_clean1/qanda-v2/.venv/bin/python

# %%
import sys
print("Python path:", sys.executable)

# Test core imports
import pandas as pd
import chromadb
import openai
print("✅ Core imports successful!")
# Out:
# Python path: /Users/swang/workspace/repos/qanda_clean1/qanda-v2/.venv/bin/python
# ✅ Core imports successful!
